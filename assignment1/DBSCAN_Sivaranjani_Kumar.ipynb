# %%
#DBSCAN- Density Based Spatial Clustering of Application with Noise

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("/Users/ranjani/Downloads/AQ_Boston_Cam-Quincy.csv", header=0)
#data.head()
data.head()
# Out:
#              ['location'                      'city'  'country'  \
# 0          ['Portsmouth'   'Boston-Cambridge-Quincy'       'US'
# 1  ['Odiorne State Park'   'Boston-Cambridge-Quincy'       'US'
# 2          ['Portsmouth'   'Boston-Cambridge-Quincy'       'US'
# 3          ['Portsmouth'   'Boston-Cambridge-Quincy'       'US'
# 4                ['LYNN'   'Boston-Cambridge-Quincy'       'US'
#
#                          'utc'                       'local'  'parameter'  \
# 0   '2020-02-09T18:00:00.000Z'   '2020-02-09T13:00:00-05:00'         'o3'
# 1   '2020-02-09T18:00:00.000Z'   '2020-02-09T13:00:00-05:00'         'o3'
# 2   '2020-02-09T18:00:00.000Z'   '2020-02-09T13:00:00-05:00'       'pm10'
# 3   '2020-02-09T18:00:00.000Z'   '2020-02-09T13:00:00-05:00'       'pm25'
# 4   '2020-02-09T17:00:00.000Z'   '2020-02-09T12:00:00-05:00'        'no2'
#
#     'value'    'unit'    'latitude'    'longitude'  \
# 0   '0.035'     'ppm'   '43.075371'   '-70.748017'
# 1   '0.038'     'ppm'   '43.045269'   '-70.713958'
# 2      '10'   'µg/m³'   '43.075371'   '-70.748017'
# 3     '4.8'   'µg/m³'   '43.075371'   '-70.748017'
# 4   '0.008'     'ppm'   '42.474701'   '-70.971901'
#
#                'attribution']                    Unnamed: 11  \
# 0   '[{"name":"US EPA AirNow"  url:"http://www.airnow.gov/"}
# 1   '[{"name":"US EPA AirNow"  url:"http://www.airnow.gov/"}
# 2   '[{"name":"US EPA AirNow"  url:"http://www.airnow.gov/"}
# 3   '[{"name":"US EPA AirNow"  url:"http://www.airnow.gov/"}
# 4   '[{"name":"US EPA AirNow"  url:"http://www.airnow.gov/"}
#
#                                          Unnamed: 12
# 0  {"name":"New Hampshire Dept. of Environmental ...
# 1  {"name":"New Hampshire Dept. of Environmental ...
# 2  {"name":"New Hampshire Dept. of Environmental ...
# 3  {"name":"New Hampshire Dept. of Environmental ...
# 4  {"name":"Massachusetts Dept. of Environmental ...

# %%
data = data.apply(lambda s:s.str.replace('\'', "").str.replace('[', ""))
data.columns = data.columns.str.strip().str.replace('[', '').str.replace(']', '').str.replace('\'','')
data.drop(data.columns[[10,11,12]], axis=1, inplace=True)
data.head()
# Out:
#              location                      city country  \
# 0          Portsmouth   Boston-Cambridge-Quincy      US
# 1  Odiorne State Park   Boston-Cambridge-Quincy      US
# 2          Portsmouth   Boston-Cambridge-Quincy      US
# 3          Portsmouth   Boston-Cambridge-Quincy      US
# 4                LYNN   Boston-Cambridge-Quincy      US
#
#                          utc                       local parameter   value  \
# 0   2020-02-09T18:00:00.000Z   2020-02-09T13:00:00-05:00        o3   0.035
# 1   2020-02-09T18:00:00.000Z   2020-02-09T13:00:00-05:00        o3   0.038
# 2   2020-02-09T18:00:00.000Z   2020-02-09T13:00:00-05:00      pm10      10
# 3   2020-02-09T18:00:00.000Z   2020-02-09T13:00:00-05:00      pm25     4.8
# 4   2020-02-09T17:00:00.000Z   2020-02-09T12:00:00-05:00       no2   0.008
#
#      unit    latitude    longitude
# 0     ppm   43.075371   -70.748017
# 1     ppm   43.045269   -70.713958
# 2   µg/m³   43.075371   -70.748017
# 3   µg/m³   43.075371   -70.748017
# 4     ppm   42.474701   -70.971901

# %%
data["location"] = data["location"].astype('category')
data["location"] = data["location"].cat.codes
data["local"] = data["local"].astype('category')
data["local"] = data["local"].cat.codes
data.dtypes
# Out:
# location       int8
# city         object
# country      object
# utc          object
# local         int16
# parameter    object
# value        object
# unit         object
# latitude     object
# longitude    object
# dtype: object

# %%
table = pd.pivot_table(data, values='value', index=['location', 'local'], columns=['parameter'], aggfunc=np.sum, fill_value=0)
table.reset_index(inplace=True)
table.columns=table.columns.str.strip()
table['co'] = table['co'].astype(float)
table['no2'] = table['no2'].astype(float)
table['o3'] = table['o3'].astype(float)
table['pm10'] = table['pm10'].astype(float)
table['pm25'] = table['pm25'].astype(float)
table['so2'] = table['so2'].astype(float)
#table['co'] = table['co'].apply(lambda x: '{:.2f}'.format(x)).astype(float)
table
# Out:
# parameter  location  local   co    no2     o3  pm10  pm25    so2
# 0                 0      0  0.0  0.008  0.000   0.0   0.0  0.000
# 1                 0      1  0.0  0.009  0.000   0.0   0.0  0.000
# 2                 0      2  0.0  0.008  0.000   0.0   0.0  0.000
# 3                 0      3  0.0  0.008  0.000   0.0   0.0  0.000
# 4                 0      4  0.0  0.007  0.000   0.0   0.0  0.000
# 5                 0      5  0.0  0.011  0.000   0.0   0.0  0.000
# 6                 0      6  0.0  0.014  0.000   0.0   0.0  0.000
# 7                 0      7  0.0  0.009  0.000   0.0   0.0  0.000
# 8                 0      8  0.0  0.009  0.000   0.0   0.0  0.000
# 9                 0      9  0.0  0.009  0.000   0.0   0.0  0.000
# 10                0     10  0.0  0.009  0.000   0.0   0.0  0.000
# 11                0     11  0.0  0.011  0.000   0.0   0.0  0.000
# 12                0     12  0.0  0.018  0.000   0.0   0.0  0.000
# 13                0     13  0.0  0.024  0.000   0.0   0.0  0.001
# 14                0     14  0.0  0.024  0.000   0.0   0.0  0.001
# 15                0     15  0.0  0.021  0.000   0.0   0.0  0.001
# 16                0     16  0.0  0.021  0.000   0.0   0.0  0.001
# 17                0     17  0.0  0.021  0.000   0.0   0.0  0.001
# 18                0     18  0.0  0.020  0.000   0.0   0.0  0.001
# 19                0     19  0.0  0.019  0.000   0.0   0.0  0.000
# 20                0     20  0.0  0.021  0.000   0.0   0.0  0.001
# 21                0     21  0.0  0.021  0.000   0.0   0.0  0.000
# 22                0     22  0.0  0.025  0.000   0.0   0.0  0.000
# 23                0     23  0.0  0.029  0.000   0.0   0.0  0.001
# 24                0     24  0.0  0.038  0.000   0.0   0.0  0.001
# 25                0     25  0.0  0.041  0.000   0.0   0.0  0.001
# 26                0     26  0.0  0.039  0.000   0.0   0.0  0.001
# 27                0     27  0.0  0.033  0.000   0.0   0.0  0.001
# 28                0     44  0.0  0.002  0.000   0.0   0.0  0.002
# 29                0     45  0.0  0.008  0.000   0.0   0.0  0.002
# ...             ...    ...  ...    ...    ...   ...   ...    ...
# 3837              7    511  0.0  0.000  0.033   6.0   3.2  0.002
# 3838              7    512  0.0  0.000  0.036  11.0   3.1  0.002
# 3839              7    513  0.0  0.000  0.037  12.0   3.2  0.002
# 3840              7    514  0.0  0.000  0.038  11.0   3.0  0.002
# 3841              7    515  0.0  0.000  0.037   8.0   3.1  0.002
# 3842              7    516  0.0  0.000  0.037  10.0   3.2  0.002
# 3843              7    517  0.0  0.000  0.037   8.0   3.1  0.002
# 3844              7    518  0.0  0.000  0.036   8.0   3.1  0.002
# 3845              7    519  0.0  0.000  0.037   8.0   3.1  0.002
# 3846              7    520  0.0  0.000  0.035   8.0   3.4  0.002
# 3847              7    521  0.0  0.000  0.035   9.0   4.1  0.002
# 3848              7    522  0.0  0.000  0.036   8.0   4.1  0.002
# 3849              7    523  0.0  0.000  0.036  22.0   6.1  0.002
# 3850              7    524  0.0  0.000  0.034  13.0   5.5  0.002
# 3851              7    525  0.0  0.000  0.034  22.0   7.1  0.002
# 3852              7    526  0.0  0.000  0.030  22.0   6.9  0.002
# 3853              7    527  0.0  0.000  0.029   9.0   5.1  0.000
# 3854              7    528  0.0  0.000  0.029   9.0   4.7  0.002
# 3855              7    529  0.0  0.000  0.031   7.0   4.0  0.002
# 3856              7    530  0.0  0.000  0.029  14.0   5.3  0.002
# 3857              7    531  0.0  0.000  0.000   8.0   5.5  0.002
# 3858              7    532  0.0  0.000  0.032   9.0   5.3  0.002
# 3859              7    533  0.0  0.000  0.025   9.0   6.0  0.002
# 3860              7    534  0.0  0.000  0.026  11.0   6.4  0.002
# 3861              7    535  0.0  0.000  0.029  47.0  10.2  0.003
# 3862              7    536  0.0  0.000  0.000  71.0  13.8  0.006
# 3863              7    537  0.0  0.000  0.034  66.0  13.0  0.004
# 3864              7    538  0.0  0.000  0.036  30.0   6.8  0.004
# 3865              7    539  0.0  0.000  0.035  16.0   5.3  0.003
# 3866              7    540  0.0  0.000  0.035  10.0   4.8  0.000
#
# [3867 rows x 8 columns]

# %%
X = table.iloc[:,[4,5]].values

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# cluster the data into five clusters
dbscan = DBSCAN(eps=0.123, min_samples = 2)
clusters = dbscan.fit_predict(X_scaled)

# plot the cluster assignments
plt.scatter(X[:, 0], X[:, 1], c=clusters, cmap="plasma")
plt.xlabel("O3")
plt.ylabel("PM10")
# Out:
# Text(0, 0.5, 'PM10')
